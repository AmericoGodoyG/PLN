# %%
# !pip install sounddevice spicy openai-whisper
# Out:
# Collecting sounddevice
#   Downloading sounddevice-0.5.5-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting spicy
#   Downloading spicy-0.16.0-py2.py3-none-any.whl.metadata (310 bytes)
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 803.2/803.2 kB 8.6 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: cffi in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: scipy in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spicy) (1.17.1)
# Collecting more-itertools (from openai-whisper)
#   Downloading more_itertools-11.0.1-py3-none-any.whl.metadata (41 kB)
# Collecting numba (from openai-whisper)
#   Downloading numba-0.65.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai-whisper) (2.4.2)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting torch (from openai-whisper)
#   Downloading torch-2.11.0-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: tqdm in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai-whisper) (4.67.3)
# Requirement already satisfied: pycparser in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cffi->sounddevice) (3.0)
# Collecting llvmlite<0.48,>=0.47.0dev0 (from numba->openai-whisper)
#   Downloading llvmlite-0.47.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting regex>=2022.1.18 (from tiktoken->openai-whisper)
#   Downloading regex-2026.4.4-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tiktoken->openai-whisper) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2026.1.4)
# Collecting filelock (from torch->openai-whisper)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch->openai-whisper) (4.15.0)
# Collecting setuptools<82 (from torch->openai-whisper)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch->openai-whisper)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->openai-whisper)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch->openai-whisper) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch->openai-whisper)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->openai-whisper)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch->openai-whisper) (3.0.3)
# Requirement already satisfied: colorama in C:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm->openai-whisper) (0.4.6)
# Downloading sounddevice-0.5.5-py3-none-win_amd64.whl (365 kB)
# Downloading spicy-0.16.0-py2.py3-none-any.whl (1.7 kB)
# Downloading more_itertools-11.0.1-py3-none-any.whl (72 kB)
# Downloading numba-0.65.0-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 17.6 MB/s  0:00:00
# Downloading llvmlite-0.47.0-cp312-cp312-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------- ----------------------------- 10.0/38.1 MB 47.8 MB/s eta 0:00:01
#    --------------------------------- ------ 32.0/38.1 MB 77.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 67.3 MB/s  0:00:00
# Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl (878 kB)
#    ---------------------------------------- 0.0/878.7 kB ? eta -:--:--
#    ---------------------------------------- 878.7/878.7 kB ?  0:00:00
# Downloading regex-2026.4.4-cp312-cp312-win_amd64.whl (277 kB)
# Downloading torch-2.11.0-cp312-cp312-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    -------- ------------------------------ 25.2/114.6 MB 122.7 MB/s eta 0:00:01
#    ----------------- --------------------- 50.3/114.6 MB 118.6 MB/s eta 0:00:01
#    ------------------------- ------------- 75.5/114.6 MB 117.4 MB/s eta 0:00:01
#    -------------------------------- ------ 95.7/114.6 MB 113.1 MB/s eta 0:00:01
#    -------------------------------------  111.9/114.6 MB 106.7 MB/s eta 0:00:01
#    -------------------------------------  114.3/114.6 MB 105.8 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 MB 91.4 MB/s  0:00:01
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 53.3 MB/s  0:00:00
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 56.4 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 77.4 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB ?  0:00:00
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml): started
#   Building wheel for openai-whisper (pyproject.toml): finished with status 'done'
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=804012 sha256=8cda18ac86c1d6c394d7cbb924d1cf3a5edef67e4af830a53bcdb8280fe8f0d8
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\61\d2\20\09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# Installing collected packages: mpmath, sympy, setuptools, regex, networkx, more-itertools, llvmlite, fsspec, filelock, torch, tiktoken, spicy, sounddevice, numba, openai-whisper
#
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#   Attempting uninstall: setuptools
#    -- -------------------------------------  1/15 [sympy]
#     Found existing installation: setuptools 82.0.0
#    -- -------------------------------------  1/15 [sympy]
#    ----- ----------------------------------  2/15 [setuptools]
#     Uninstalling setuptools-82.0.0:
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#       Successfully uninstalled setuptools-82.0.0
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    ----- ----------------------------------  2/15 [setuptools]
#    -------- -------------------------------  3/15 [regex]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ------------- --------------------------  5/15 [more-itertools]
#    ---------------- -----------------------  6/15 [llvmlite]
#    ---------------- -----------------------  6/15 [llvmlite]
#    ---------------- -----------------------  6/15 [llvmlite]
#    ---------------- -----------------------  6/15 [llvmlite]
#    ------------------ ---------------------  7/15 [fsspec]
#    ------------------ ---------------------  7/15 [fsspec]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------- ----- 13/15 [numba]
#    ---------------------------------------- 15/15 [openai-whisper]
#
# Successfully installed filelock-3.25.2 fsspec-2026.3.0 llvmlite-0.47.0 more-itertools-11.0.1 mpmath-1.3.0 networkx-3.6.1 numba-0.65.0 openai-whisper-20250625 regex-2026.4.4 setuptools-81.0.0 sounddevice-0.5.5 spicy-0.16.0 sympy-1.14.0 tiktoken-0.12.0 torch-2.11.0

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import whisper
from datetime import datetime

# %%
def gravar_audio(nome_arquivo="audio.wav", duracao=5, fs=44100):
    print("Gravando áudio....")
    audio = sd.rec(int(duracao * fs), samplerate=fs, channels=1)
    sd.wait()
    write(nome_arquivo, fs, audio)
    print("Gravação finalizada!")

# %% [markdown]
# ### Carregando o modelo Whisper
#
# | Modelo | Tamanho | Qualidade | Velocidade   |
# | ------ | ------- | --------- | ------------ |
# | tiny   | ~75 MB  | baixa     | muito rápido |
# | base   | ~150 MB | boa       | rápido       |
# | small  | ~500 MB | melhor    | médio        |
# | medium | ~1.5 GB | alta      | mais lento   |
# | large  | ~3 GB   | excelente | pesado       |

# %%
print("Carregando modelo...")
model = whisper.load_model("small")
print("Modelo carregado!")
# Out:
# Carregando modelo...
# 100%|███████████████████████████████████████| 461M/461M [00:05<00:00, 92.9MiB/s]
# Modelo carregado!

# %%
def transcrever_audio(nome_arquivo="audio.wav"):
    print("Transcrevendo áudio...")
    result = model.transcribe(nome_arquivo, language='pt')
    texto = result["text"]
    print("Texto:", texto)
    return texto.lower()

# %%
def classificar_comando(texto):
    if "luz" in texto and "ligar" in texto:
        print("Ligando a luz")
    
    elif "luz" in texto and "desligar" in texto:
        print(" Desligando a luz")
    
    elif "hora" in texto:
        print(" Agora são:", datetime.now().strftime("%H:%M"))

    elif "data" in texto:
        print(" Hoje é:", datetime.now().strftime("%d/%m/%Y"))

    else:
        print("Comando não reconhecido")
